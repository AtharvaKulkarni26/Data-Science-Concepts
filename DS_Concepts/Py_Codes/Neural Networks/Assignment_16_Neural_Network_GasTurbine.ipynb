# %% [markdown]
# ## Neural Network
# ### Gas Turbines

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import cross_val_score

# %%
turbine= pd.read_csv('gas_turbines.csv')

# %%
turbine.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
# Normalization function 
def norm_func(i):
     x = (i-i.min())	/	(i.max()	-	i.min())
     return (x)
gasturbine = norm_func(turbine)

# %%
x=pd.DataFrame(gasturbine, columns= ['AT','AP','AH','AFDP','GTEP','TIT','TAT','CDP','CO','NOX'])
y=gasturbine.TEY

# %%
# Tuning hyperparameters- Batch size and epochs

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.wrappers.scikit_learn import KerasRegressor
from keras.optimizers import Adam

# %%
# create a sequential model
def create_model():
  model= Sequential()
  model.add(Dense(10, input_dim=10, kernel_initializer= 'normal', activation='relu'))
  model.add(Dense(8, kernel_initializer= 'normal', activation='relu'))
  model.add(Dense(8, kernel_initializer= 'normal', activation='relu'))
  model.add(Dense(1, kernel_initializer= 'normal')) 
  adam= Adam()
# Compile model
  model.compile(loss='mean_squared_error', optimizer=adam)
  return model

# %%
# create regression model
model= KerasRegressor(build_fn=create_model, verbose=0)
# create grid search model
batch_size=[50,100, 200, 400, 800, 1000]
epochs=[10,50,100]
# Make a dictionary of grid search parameters
param_grid= dict(batch_size= batch_size, epochs=epochs)
#build and fit the gridsearchCV
grid= GridSearchCV(estimator=model, param_grid=param_grid, cv= KFold(), verbose=10 )
grid_result= grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] batch_size=50, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........... batch_size=50, epochs=10, score=-0.000, total=   2.6s
# [CV] batch_size=50, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=10, score=-0.000, total=   2.1s
# [CV] batch_size=50, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=10, score=-0.000, total=   2.3s
# [CV] batch_size=50, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.9s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=10, score=-0.000, total=   2.0s
# [CV] batch_size=50, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    8.9s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=10, score=-0.000, total=   1.9s
# [CV] batch_size=50, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   10.8s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=50, score=-0.000, total=   7.2s
# [CV] batch_size=50, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   18.1s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=50, score=-0.000, total=   7.8s
# [CV] batch_size=50, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   25.8s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=50, score=-0.000, total=   6.4s
# [CV] batch_size=50, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   32.2s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=50, score=-0.000, total=   6.5s
# [CV] batch_size=50, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   38.7s remaining:    0.0s
# [CV] ........... batch_size=50, epochs=50, score=-0.000, total=   6.4s
# [CV] batch_size=50, epochs=100 .......................................
# [CV] .......... batch_size=50, epochs=100, score=-0.000, total=  13.0s
# [CV] batch_size=50, epochs=100 .......................................
# [CV] .......... batch_size=50, epochs=100, score=-0.000, total=  12.5s
# [CV] batch_size=50, epochs=100 .......................................
# [CV] .......... batch_size=50, epochs=100, score=-0.000, total=  12.7s
# [CV] batch_size=50, epochs=100 .......................................
# [CV] .......... batch_size=50, epochs=100, score=-0.000, total=  12.3s
# [CV] batch_size=50, epochs=100 .......................................
# [CV] .......... batch_size=50, epochs=100, score=-0.000, total=  12.0s
# [CV] batch_size=100, epochs=10 .......................................
# [CV] .......... batch_size=100, epochs=10, score=-0.001, total=   1.2s
# [CV] batch_size=100, epochs=10 .......................................
# [CV] .......... batch_size=100, epochs=10, score=-0.000, total=   1.2s
# [CV] batch_size=100, epochs=10 .......................................
# [CV] .......... batch_size=100, epochs=10, score=-0.000, total=   1.4s
# [CV] batch_size=100, epochs=10 .......................................
# [CV] .......... batch_size=100, epochs=10, score=-0.000, total=   1.2s
# [CV] batch_size=100, epochs=10 .......................................
# [CV] .......... batch_size=100, epochs=10, score=-0.000, total=   1.3s
# [CV] batch_size=100, epochs=50 .......................................
# [CV] .......... batch_size=100, epochs=50, score=-0.000, total=   3.6s
# [CV] batch_size=100, epochs=50 .......................................
# [CV] .......... batch_size=100, epochs=50, score=-0.000, total=   4.0s
# [CV] batch_size=100, epochs=50 .......................................
# [CV] .......... batch_size=100, epochs=50, score=-0.000, total=   3.7s
# [CV] batch_size=100, epochs=50 .......................................
# [CV] .......... batch_size=100, epochs=50, score=-0.000, total=   3.7s
# [CV] batch_size=100, epochs=50 .......................................
# [CV] .......... batch_size=100, epochs=50, score=-0.000, total=   3.7s
# [CV] batch_size=100, epochs=100 ......................................
# [CV] ......... batch_size=100, epochs=100, score=-0.000, total=   7.1s
# [CV] batch_size=100, epochs=100 ......................................
# [CV] ......... batch_size=100, epochs=100, score=-0.000, total=   6.8s
# [CV] batch_size=100, epochs=100 ......................................
# [CV] ......... batch_size=100, epochs=100, score=-0.000, total=   7.7s
# [CV] batch_size=100, epochs=100 ......................................
# [CV] ......... batch_size=100, epochs=100, score=-0.000, total=   9.7s
# [CV] batch_size=100, epochs=100 ......................................
# [CV] ......... batch_size=100, epochs=100, score=-0.000, total=   6.8s
# [CV] batch_size=200, epochs=10 .......................................
# [CV] .......... batch_size=200, epochs=10, score=-0.002, total=   0.9s
# [CV] batch_size=200, epochs=10 .......................................
# [CV] .......... batch_size=200, epochs=10, score=-0.000, total=   0.9s
# [CV] batch_size=200, epochs=10 .......................................
# [CV] .......... batch_size=200, epochs=10, score=-0.001, total=   1.1s
# [CV] batch_size=200, epochs=10 .......................................
# [CV] .......... batch_size=200, epochs=10, score=-0.000, total=   0.9s
# [CV] batch_size=200, epochs=10 .......................................
# [CV] .......... batch_size=200, epochs=10, score=-0.001, total=   1.0s
# [CV] batch_size=200, epochs=50 .......................................
# [CV] .......... batch_size=200, epochs=50, score=-0.000, total=   2.2s
# [CV] batch_size=200, epochs=50 .......................................
# [CV] .......... batch_size=200, epochs=50, score=-0.000, total=   2.4s
# [CV] batch_size=200, epochs=50 .......................................
# [CV] .......... batch_size=200, epochs=50, score=-0.000, total=   2.3s
# [CV] batch_size=200, epochs=50 .......................................
# [CV] .......... batch_size=200, epochs=50, score=-0.000, total=   2.2s
# [CV] batch_size=200, epochs=50 .......................................
# [CV] .......... batch_size=200, epochs=50, score=-0.000, total=   2.4s
# [CV] batch_size=200, epochs=100 ......................................
# [CV] ......... batch_size=200, epochs=100, score=-0.000, total=   3.8s
# [CV] batch_size=200, epochs=100 ......................................
# [CV] ......... batch_size=200, epochs=100, score=-0.000, total=   3.9s
# [CV] batch_size=200, epochs=100 ......................................
# [CV] ......... batch_size=200, epochs=100, score=-0.000, total=   3.8s
# [CV] batch_size=200, epochs=100 ......................................
# [CV] ......... batch_size=200, epochs=100, score=-0.000, total=   4.1s
# [CV] batch_size=200, epochs=100 ......................................
# [CV] ......... batch_size=200, epochs=100, score=-0.000, total=   3.9s
# [CV] batch_size=400, epochs=10 .......................................
# [CV] .......... batch_size=400, epochs=10, score=-0.001, total=   0.8s
# [CV] batch_size=400, epochs=10 .......................................
# [CV] .......... batch_size=400, epochs=10, score=-0.000, total=   0.8s
# [CV] batch_size=400, epochs=10 .......................................
# [CV] .......... batch_size=400, epochs=10, score=-0.002, total=   1.0s
# [CV] batch_size=400, epochs=10 .......................................
# [CV] .......... batch_size=400, epochs=10, score=-0.000, total=   0.8s
# [CV] batch_size=400, epochs=10 .......................................
# [CV] .......... batch_size=400, epochs=10, score=-0.013, total=   0.8s
# [CV] batch_size=400, epochs=50 .......................................
# [CV] .......... batch_size=400, epochs=50, score=-0.000, total=   1.5s
# [CV] batch_size=400, epochs=50 .......................................
# [CV] .......... batch_size=400, epochs=50, score=-0.000, total=   1.7s
# [CV] batch_size=400, epochs=50 .......................................
# [CV] .......... batch_size=400, epochs=50, score=-0.000, total=   1.5s
# [CV] batch_size=400, epochs=50 .......................................
# [CV] .......... batch_size=400, epochs=50, score=-0.000, total=   1.7s
# [CV] batch_size=400, epochs=50 .......................................
# [CV] .......... batch_size=400, epochs=50, score=-0.000, total=   1.9s
# [CV] batch_size=400, epochs=100 ......................................
# [CV] ......... batch_size=400, epochs=100, score=-0.000, total=   2.7s
# [CV] batch_size=400, epochs=100 ......................................
# [CV] ......... batch_size=400, epochs=100, score=-0.000, total=   2.4s
# [CV] batch_size=400, epochs=100 ......................................
# [CV] ......... batch_size=400, epochs=100, score=-0.000, total=   2.4s
# [CV] batch_size=400, epochs=100 ......................................
# [CV] ......... batch_size=400, epochs=100, score=-0.000, total=   2.6s
# [CV] batch_size=400, epochs=100 ......................................
# [CV] ......... batch_size=400, epochs=100, score=-0.000, total=   2.4s
# [CV] batch_size=800, epochs=10 .......................................
# [CV] .......... batch_size=800, epochs=10, score=-0.044, total=   0.7s
# [CV] batch_size=800, epochs=10 .......................................
# [CV] .......... batch_size=800, epochs=10, score=-0.018, total=   0.7s
# [CV] batch_size=800, epochs=10 .......................................
# [CV] .......... batch_size=800, epochs=10, score=-0.030, total=   0.9s
# [CV] batch_size=800, epochs=10 .......................................
# [CV] .......... batch_size=800, epochs=10, score=-0.018, total=   0.7s
# [CV] batch_size=800, epochs=10 .......................................
# [CV] .......... batch_size=800, epochs=10, score=-0.035, total=   0.7s
# [CV] batch_size=800, epochs=50 .......................................
# [CV] .......... batch_size=800, epochs=50, score=-0.001, total=   1.3s
# [CV] batch_size=800, epochs=50 .......................................
# [CV] .......... batch_size=800, epochs=50, score=-0.000, total=   1.3s
# [CV] batch_size=800, epochs=50 .......................................
# [CV] .......... batch_size=800, epochs=50, score=-0.000, total=   1.1s
# [CV] batch_size=800, epochs=50 .......................................
# [CV] .......... batch_size=800, epochs=50, score=-0.000, total=   1.1s
# [CV] batch_size=800, epochs=50 .......................................
# [CV] .......... batch_size=800, epochs=50, score=-0.000, total=   1.3s
# [CV] batch_size=800, epochs=100 ......................................
# [CV] ......... batch_size=800, epochs=100, score=-0.000, total=   1.7s
# [CV] batch_size=800, epochs=100 ......................................
# [CV] ......... batch_size=800, epochs=100, score=-0.000, total=   1.6s
# [CV] batch_size=800, epochs=100 ......................................
# [CV] ......... batch_size=800, epochs=100, score=-0.000, total=   1.7s
# [CV] batch_size=800, epochs=100 ......................................
# [CV] ......... batch_size=800, epochs=100, score=-0.000, total=   2.1s
# [CV] batch_size=800, epochs=100 ......................................
# [CV] ......... batch_size=800, epochs=100, score=-0.000, total=   1.8s
# [CV] batch_size=1000, epochs=10 ......................................
# [CV] ......... batch_size=1000, epochs=10, score=-0.045, total=   0.7s
# [CV] batch_size=1000, epochs=10 ......................................
# [CV] ......... batch_size=1000, epochs=10, score=-0.021, total=   0.7s
# [CV] batch_size=1000, epochs=10 ......................................
# [CV] ......... batch_size=1000, epochs=10, score=-0.045, total=   0.8s
# [CV] batch_size=1000, epochs=10 ......................................
# [CV] ......... batch_size=1000, epochs=10, score=-0.030, total=   0.7s
# [CV] batch_size=1000, epochs=10 ......................................
# [CV] ......... batch_size=1000, epochs=10, score=-0.038, total=   0.7s
# [CV] batch_size=1000, epochs=50 ......................................
# [CV] ......... batch_size=1000, epochs=50, score=-0.000, total=   1.2s
# [CV] batch_size=1000, epochs=50 ......................................
# [CV] ......... batch_size=1000, epochs=50, score=-0.000, total=   1.1s
# [CV] batch_size=1000, epochs=50 ......................................
# [CV] ......... batch_size=1000, epochs=50, score=-0.001, total=   1.1s
# [CV] batch_size=1000, epochs=50 ......................................
# [CV] ......... batch_size=1000, epochs=50, score=-0.001, total=   1.1s
# [CV] batch_size=1000, epochs=50 ......................................
# [CV] ......... batch_size=1000, epochs=50, score=-0.000, total=   1.2s
# [CV] batch_size=1000, epochs=100 .....................................
# [CV] ........ batch_size=1000, epochs=100, score=-0.000, total=   1.5s
# [CV] batch_size=1000, epochs=100 .....................................
# [CV] ........ batch_size=1000, epochs=100, score=-0.000, total=   1.5s
# [CV] batch_size=1000, epochs=100 .....................................
# [CV] ........ batch_size=1000, epochs=100, score=-0.000, total=   1.8s
# [CV] batch_size=1000, epochs=100 .....................................
# [CV] ........ batch_size=1000, epochs=100, score=-0.000, total=   2.2s
# [CV] batch_size=1000, epochs=100 .....................................
# [CV] ........ batch_size=1000, epochs=100, score=-0.000, total=   1.6s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:  4.5min finished

# %%
# summerize results
print('Best:{}, using {}'.format(grid_result.best_score_, grid_result.best_params_))
means= grid_result.cv_results_['mean_test_score']
stds= grid_result.cv_results_['std_test_score']
params= grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best:-0.00011987785255769267, using {'batch_size': 200, 'epochs': 100}
# -0.0001406989002134651,3.203665163580116e-05 with: {'batch_size': 50, 'epochs': 10}
# -0.0001370648722513579,5.119737684659234e-05 with: {'batch_size': 50, 'epochs': 50}
# -0.00013694656372535973,2.7805979836906262e-05 with: {'batch_size': 50, 'epochs': 100}
# -0.0002855305763659999,0.00016743466815344232 with: {'batch_size': 100, 'epochs': 10}
# -0.00014355129096657037,3.2976362316587035e-05 with: {'batch_size': 100, 'epochs': 50}
# -0.00012351058539934457,1.275699775060439e-05 with: {'batch_size': 100, 'epochs': 100}
# -0.0009808041213545948,0.0006758302261744328 with: {'batch_size': 200, 'epochs': 10}
# -0.00014104163856245577,1.4888270766120529e-05 with: {'batch_size': 200, 'epochs': 50}
# -0.00011987785255769267,1.6623232099668437e-05 with: {'batch_size': 200, 'epochs': 100}
# -0.0033652482146862895,0.0048975508885759425 with: {'batch_size': 400, 'epochs': 10}
# -0.00018377780506853014,4.7310720242291724e-05 with: {'batch_size': 400, 'epochs': 50}
# -0.00012899751891382039,1.89267150928755e-05 with: {'batch_size': 400, 'epochs': 100}
# -0.02883788086473942,0.00990606540124605 with: {'batch_size': 800, 'epochs': 10}
# -0.0004915115976473316,0.0003069960482698126 with: {'batch_size': 800, 'epochs': 50}
# -0.000163475533190649,5.6786429934052445e-05 with: {'batch_size': 800, 'epochs': 100}
# -0.03580250404775143,0.009235648986501 with: {'batch_size': 1000, 'epochs': 10}
# -0.00043417611450422553,0.0002640403958790848 with: {'batch_size': 1000, 'epochs': 50}
# -0.00018312081665499135,6.251658908580555e-05 with: {'batch_size': 1000, 'epochs': 100}

# %%
# Tuning hyperparameter: Learning rate and drop out rate

# %%
from keras.layers import Dropout

# defining model
def create_model_lr_drate(learning_rate,dropout_rate):
  model= Sequential()
  model.add(Dense(10, input_dim=10, kernel_initializer= 'normal', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(8, kernel_initializer= 'normal', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(8, kernel_initializer= 'normal', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1, kernel_initializer= 'normal')) 
  adam= Adam(learning_rate= learning_rate)
# Compile model
  model.compile(loss='mean_squared_error', optimizer=adam)
  return model

# Define regression model
model= KerasRegressor(build_fn=create_model_lr_drate, verbose=0, batch_size=100, epochs=100)
# Define grid search model
learning_rate=[0.001, 0.01, 0.1, 0.2, 0.5]
dropout_rate=[0, 0.1, 0.2]
# Make a dictionary of grid search parameters
param_grid= dict(learning_rate= learning_rate, dropout_rate=dropout_rate)
#build and fit the gridsearchCV
grid= GridSearchCV(estimator=model, param_grid=param_grid, cv= KFold(), verbose=10 )
grid_result= grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] dropout_rate=0, learning_rate=0.001 .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  dropout_rate=0, learning_rate=0.001, score=-0.000, total=   8.7s
# [CV] dropout_rate=0, learning_rate=0.001 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.6s remaining:    0.0s
# [CV]  dropout_rate=0, learning_rate=0.001, score=-0.000, total=   8.9s
# [CV] dropout_rate=0, learning_rate=0.001 .............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   17.6s remaining:    0.0s
# [CV]  dropout_rate=0, learning_rate=0.001, score=-0.000, total=   9.7s
# [CV] dropout_rate=0, learning_rate=0.001 .............................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   27.2s remaining:    0.0s
# [CV]  dropout_rate=0, learning_rate=0.001, score=-0.000, total=   9.7s
# [CV] dropout_rate=0, learning_rate=0.001 .............................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   36.9s remaining:    0.0s
# [CV]  dropout_rate=0, learning_rate=0.001, score=-0.000, total=   8.6s
# [CV] dropout_rate=0, learning_rate=0.01 ..............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   45.5s remaining:    0.0s
# [CV] . dropout_rate=0, learning_rate=0.01, score=-0.000, total=   7.7s
# [CV] dropout_rate=0, learning_rate=0.01 ..............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   53.2s remaining:    0.0s
# [CV] . dropout_rate=0, learning_rate=0.01, score=-0.000, total=   8.0s
# [CV] dropout_rate=0, learning_rate=0.01 ..............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.0min remaining:    0.0s
# [CV] . dropout_rate=0, learning_rate=0.01, score=-0.000, total=   8.4s
# [CV] dropout_rate=0, learning_rate=0.01 ..............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.2min remaining:    0.0s
# [CV] . dropout_rate=0, learning_rate=0.01, score=-0.000, total=   8.0s
# [CV] dropout_rate=0, learning_rate=0.01 ..............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.3min remaining:    0.0s
# [CV] . dropout_rate=0, learning_rate=0.01, score=-0.000, total=   7.8s
# [CV] dropout_rate=0, learning_rate=0.1 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.1, score=-0.061, total=   8.0s
# [CV] dropout_rate=0, learning_rate=0.1 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.1, score=-0.021, total=   8.3s
# [CV] dropout_rate=0, learning_rate=0.1 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.1, score=-0.001, total=   7.9s
# [CV] dropout_rate=0, learning_rate=0.1 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.1, score=-0.048, total=   8.0s
# [CV] dropout_rate=0, learning_rate=0.1 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.1, score=-0.045, total=   8.5s
# [CV] dropout_rate=0, learning_rate=0.2 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.2, score=-0.061, total=   8.1s
# [CV] dropout_rate=0, learning_rate=0.2 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.2, score=-0.024, total=   8.4s
# [CV] dropout_rate=0, learning_rate=0.2 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.2, score=-0.066, total=   8.3s
# [CV] dropout_rate=0, learning_rate=0.2 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.2, score=-0.043, total=   8.4s
# [CV] dropout_rate=0, learning_rate=0.2 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.2, score=-0.054, total=   8.2s
# [CV] dropout_rate=0, learning_rate=0.5 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.5, score=-0.061, total=   8.2s
# [CV] dropout_rate=0, learning_rate=0.5 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.5, score=-0.028, total=   8.5s
# [CV] dropout_rate=0, learning_rate=0.5 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.5, score=-0.053, total=   8.1s
# [CV] dropout_rate=0, learning_rate=0.5 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.5, score=-0.044, total=   8.2s
# [CV] dropout_rate=0, learning_rate=0.5 ...............................
# [CV] .. dropout_rate=0, learning_rate=0.5, score=-0.051, total=   8.3s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=-0.002, total=   8.7s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=-0.002, total=   8.4s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=-0.002, total=   8.3s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=-0.000, total=   8.3s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=-0.001, total=  10.0s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=-0.002, total=   8.3s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=-0.002, total=   8.7s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=-0.002, total=   8.5s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=-0.006, total=   8.2s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=-0.003, total=   8.2s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.1, score=-0.012, total=   8.7s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.1, score=-0.023, total=   8.4s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.1, score=-0.053, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.1, score=-0.043, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.1, score=-0.053, total=   8.8s
# [CV] dropout_rate=0.1, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.2, score=-0.060, total=   9.9s
# [CV] dropout_rate=0.1, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.2, score=-0.022, total=   9.3s
# [CV] dropout_rate=0.1, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.2, score=-0.064, total=  10.1s
# [CV] dropout_rate=0.1, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.2, score=-0.047, total=   8.4s
# [CV] dropout_rate=0.1, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.2, score=-0.047, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.5, score=-0.062, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.5, score=-0.024, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.5, score=-0.059, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.5, score=-0.043, total=   8.6s
# [CV] dropout_rate=0.1, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.1, learning_rate=0.5, score=-0.047, total=   8.6s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=-0.002, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=-0.004, total=   8.7s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=-0.002, total=   8.9s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=-0.006, total=   8.6s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=-0.006, total=   8.6s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=-0.018, total=   8.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=-0.008, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=-0.004, total=   8.6s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=-0.003, total=   8.6s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=-0.005, total=   8.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.1, score=-0.060, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.1, score=-0.021, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.1, score=-0.052, total=   8.4s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.1, score=-0.046, total=   8.4s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.1, score=-0.054, total=   8.4s
# [CV] dropout_rate=0.2, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.2, score=-0.060, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.2, score=-0.023, total=   8.8s
# [CV] dropout_rate=0.2, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.2, score=-0.065, total=   8.6s
# [CV] dropout_rate=0.2, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.2, score=-0.043, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.2 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.2, score=-0.047, total=   9.2s
# [CV] dropout_rate=0.2, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.5, score=-0.064, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.5, score=-0.019, total=   8.5s
# [CV] dropout_rate=0.2, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.5, score=-0.052, total=  10.2s
# [CV] dropout_rate=0.2, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.5, score=-0.043, total=  10.2s
# [CV] dropout_rate=0.2, learning_rate=0.5 .............................
# [CV]  dropout_rate=0.2, learning_rate=0.5, score=-0.045, total=  10.4s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed: 10.8min finished

# %%
# summerize results
print('Best:{}, using {}'.format(grid_result.best_score_, grid_result.best_params_))
means= grid_result.cv_results_['mean_test_score']
stds= grid_result.cv_results_['std_test_score']
params= grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best:-0.00012165591033408418, using {'dropout_rate': 0, 'learning_rate': 0.001}
# -0.00012165591033408418,2.0248910047606907e-05 with: {'dropout_rate': 0, 'learning_rate': 0.001}
# -0.00019555986800696702,4.8506428411961816e-05 with: {'dropout_rate': 0, 'learning_rate': 0.01}
# -0.035069426405243576,0.02160765851374037 with: {'dropout_rate': 0, 'learning_rate': 0.1}
# -0.04961092919111252,0.015072834208051672 with: {'dropout_rate': 0, 'learning_rate': 0.2}
# -0.0471710704267025,0.011297457886479075 with: {'dropout_rate': 0, 'learning_rate': 0.5}
# -0.0013319837453309447,0.0005422995253323056 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# -0.00294589854311198,0.0016829207672788566 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# -0.036883247643709184,0.01649971848989687 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# -0.04823837839066982,0.014722925117652403 with: {'dropout_rate': 0.1, 'learning_rate': 0.2}
# -0.0469842430204153,0.013373564934015323 with: {'dropout_rate': 0.1, 'learning_rate': 0.5}
# -0.0041193377925083045,0.0018572010997433424 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# -0.007524891151115298,0.005332977811866264 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# -0.046675777062773705,0.013664166817392999 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}
# -0.047856411710381505,0.01481689267309965 with: {'dropout_rate': 0.2, 'learning_rate': 0.2}
# -0.044610343500971796,0.014661694384812327 with: {'dropout_rate': 0.2, 'learning_rate': 0.5}

# %%
# Tuning hyperparameters: Activation function and Kernal intitilizer

# %%
def create_model_af_ker_ini(activation_function,init):
  model= Sequential()
  model.add(Dense(10, input_dim=10, kernel_initializer= init, activation=activation_function))
  model.add(Dropout(0))
  model.add(Dense(8, kernel_initializer= init, activation=activation_function))
  model.add(Dropout(0))
  model.add(Dense(8, kernel_initializer= init, activation=activation_function))
  model.add(Dropout(0))
  model.add(Dense(1, kernel_initializer= init, activation='linear')) 
  adam= Adam(learning_rate= 0.001)
# Compile model
  model.compile(loss='mean_squared_error', optimizer=adam)
  return model

# Define regression model
model= KerasRegressor(build_fn=create_model_af_ker_ini, verbose=0, batch_size=100, epochs=100)
# Define grid search model
activation_function=['linear', 'relu']
init=['uniform', 'normal', 'zero']
# Make a dictionary of grid search parameters
param_grid= dict(activation_function= activation_function, init=init)
#build and fit the gridsearchCV
grid= GridSearchCV(estimator=model, param_grid=param_grid, cv= KFold(), verbose=10 )
grid_result= grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] activation_function=linear, init=uniform ........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=linear, init=uniform, score=-0.000, total=   8.5s
# [CV] activation_function=linear, init=uniform ........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.4s remaining:    0.0s
# [CV]  activation_function=linear, init=uniform, score=-0.000, total=   7.9s
# [CV] activation_function=linear, init=uniform ........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   16.3s remaining:    0.0s
# [CV]  activation_function=linear, init=uniform, score=-0.000, total=   8.2s
# [CV] activation_function=linear, init=uniform ........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   24.5s remaining:    0.0s
# [CV]  activation_function=linear, init=uniform, score=-0.000, total=   8.1s
# [CV] activation_function=linear, init=uniform ........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   32.6s remaining:    0.0s
# [CV]  activation_function=linear, init=uniform, score=-0.000, total=   9.3s
# [CV] activation_function=linear, init=normal .........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   41.9s remaining:    0.0s
# [CV]  activation_function=linear, init=normal, score=-0.000, total=  10.9s
# [CV] activation_function=linear, init=normal .........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   52.8s remaining:    0.0s
# [CV]  activation_function=linear, init=normal, score=-0.000, total=  10.1s
# [CV] activation_function=linear, init=normal .........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.0min remaining:    0.0s
# [CV]  activation_function=linear, init=normal, score=-0.000, total=  10.8s
# [CV] activation_function=linear, init=normal .........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.2min remaining:    0.0s
# [CV]  activation_function=linear, init=normal, score=-0.000, total=  11.9s
# [CV] activation_function=linear, init=normal .........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.4min remaining:    0.0s
# [CV]  activation_function=linear, init=normal, score=-0.000, total=  13.7s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=-0.061, total=  10.0s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=-0.023, total=   9.0s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=-0.057, total=  10.5s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=-0.043, total=   9.1s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=-0.047, total=   9.3s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=-0.000, total=   9.2s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=-0.000, total=   9.1s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=-0.000, total=   8.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=-0.000, total=   9.0s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=-0.000, total=   8.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=-0.000, total=   9.0s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=-0.000, total=   9.6s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=-0.000, total=   9.1s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=-0.000, total=   8.9s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=-0.000, total=   9.1s
# [CV] activation_function=relu, init=zero .............................
# [CV]  activation_function=relu, init=zero, score=-0.061, total=  19.7s
# [CV] activation_function=relu, init=zero .............................
# [CV]  activation_function=relu, init=zero, score=-0.024, total=  10.2s
# [CV] activation_function=relu, init=zero .............................
# [CV]  activation_function=relu, init=zero, score=-0.057, total=  14.6s
# [CV] activation_function=relu, init=zero .............................
# [CV]  activation_function=relu, init=zero, score=-0.043, total=  10.7s
# [CV] activation_function=relu, init=zero .............................
# [CV]  activation_function=relu, init=zero, score=-0.047, total=  17.8s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  5.2min finished

# %%
# summerize results
print('Best:{}, using {}'.format(grid_result.best_score_, grid_result.best_params_))
means= grid_result.cv_results_['mean_test_score']
stds= grid_result.cv_results_['std_test_score']
params= grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best:-0.00011123696167487651, using {'activation_function': 'linear', 'init': 'uniform'}
# -0.00011123696167487651,1.6880883714421896e-05 with: {'activation_function': 'linear', 'init': 'uniform'}
# -0.0001355608881567605,9.241769100065755e-06 with: {'activation_function': 'linear', 'init': 'normal'}
# -0.04610741250216961,0.013298208197658878 with: {'activation_function': 'linear', 'init': 'zero'}
# -0.00012110170064261183,2.2030413294213046e-05 with: {'activation_function': 'relu', 'init': 'uniform'}
# -0.00011218969884794206,2.3926885937192488e-05 with: {'activation_function': 'relu', 'init': 'normal'}
# -0.04623622000217438,0.01307135830348324 with: {'activation_function': 'relu', 'init': 'zero'}

# %%
# Tuning parameter: Number of neurons in activation layer

# %%
def create_model_neuron(neuron1,neuron2, neuron3):
  model= Sequential()
  model.add(Dense(neuron1, input_dim=10, kernel_initializer= 'normal', activation='linear'))
  model.add(Dropout(0))
  model.add(Dense(neuron2, kernel_initializer= 'normal', activation='linear'))
  model.add(Dropout(0))
  model.add(Dense(neuron3, kernel_initializer= 'normal', activation='linear'))
  model.add(Dropout(0))
  model.add(Dense(1, kernel_initializer= 'normal', activation='linear')) 
  adam= Adam(learning_rate= 0.001)
# Compile model
  model.compile(loss='mean_squared_error', optimizer=adam)
  return model

# Define regression model
model= KerasRegressor(build_fn=create_model_neuron, verbose=0, batch_size=100, epochs=100)
# Define grid search model
neuron1=[4,8,16]
neuron2=[4,8,16]
neuron3=[4,8,16]
# Make a dictionary of grid search parameters
param_grid= dict(neuron1= neuron1, neuron2=neuron2,neuron3=neuron3 )
#build and fit the gridsearchCV
grid= GridSearchCV(estimator=model, param_grid=param_grid, cv= KFold(), verbose=10 )
grid_result= grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] neuron1=4, neuron2=4, neuron3=4 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .... neuron1=4, neuron2=4, neuron3=4, score=-0.000, total=   7.9s
# [CV] neuron1=4, neuron2=4, neuron3=4 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.8s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=4, score=-0.000, total=   7.3s
# [CV] neuron1=4, neuron2=4, neuron3=4 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   15.1s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=4, score=-0.000, total=   7.2s
# [CV] neuron1=4, neuron2=4, neuron3=4 .................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   22.3s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=4, score=-0.000, total=   7.3s
# [CV] neuron1=4, neuron2=4, neuron3=4 .................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   29.6s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=4, score=-0.000, total=   7.4s
# [CV] neuron1=4, neuron2=4, neuron3=8 .................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   37.0s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=8, score=-0.000, total=   7.6s
# [CV] neuron1=4, neuron2=4, neuron3=8 .................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   44.6s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=8, score=-0.000, total=   7.4s
# [CV] neuron1=4, neuron2=4, neuron3=8 .................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   52.0s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=8, score=-0.000, total=   7.5s
# [CV] neuron1=4, neuron2=4, neuron3=8 .................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   59.5s remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=8, score=-0.000, total=   7.6s
# [CV] neuron1=4, neuron2=4, neuron3=8 .................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.1min remaining:    0.0s
# [CV] .... neuron1=4, neuron2=4, neuron3=8, score=-0.000, total=   7.4s
# [CV] neuron1=4, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=4, neuron3=16, score=-0.000, total=   7.8s
# [CV] neuron1=4, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=4, neuron3=16, score=-0.000, total=   7.9s
# [CV] neuron1=4, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=4, neuron3=16, score=-0.000, total=   8.0s
# [CV] neuron1=4, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=4, neuron3=16, score=-0.000, total=   7.7s
# [CV] neuron1=4, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=4, neuron3=16, score=-0.000, total=   7.8s
# [CV] neuron1=4, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=4, score=-0.000, total=   7.4s
# [CV] neuron1=4, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=4, score=-0.000, total=   7.4s
# [CV] neuron1=4, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=4, score=-0.000, total=   7.3s
# [CV] neuron1=4, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=4, score=-0.000, total=   7.5s
# [CV] neuron1=4, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=4, score=-0.000, total=   7.4s
# [CV] neuron1=4, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=8, score=-0.000, total=   9.6s
# [CV] neuron1=4, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=8, score=-0.000, total=  11.0s
# [CV] neuron1=4, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=8, score=-0.000, total=   9.4s
# [CV] neuron1=4, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=8, score=-0.000, total=  10.1s
# [CV] neuron1=4, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=4, neuron2=8, neuron3=8, score=-0.000, total=   9.0s
# [CV] neuron1=4, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=8, neuron3=16, score=-0.000, total=   8.4s
# [CV] neuron1=4, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=8, neuron3=16, score=-0.000, total=  10.9s
# [CV] neuron1=4, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=8, neuron3=16, score=-0.000, total=   9.4s
# [CV] neuron1=4, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=8, neuron3=16, score=-0.000, total=  12.7s
# [CV] neuron1=4, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=4, neuron2=8, neuron3=16, score=-0.000, total=  10.1s
# [CV] neuron1=4, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=4, score=-0.000, total=  11.4s
# [CV] neuron1=4, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=4, score=-0.000, total=   8.6s
# [CV] neuron1=4, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=4, score=-0.000, total=   8.7s
# [CV] neuron1=4, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=4, score=-0.000, total=  10.4s
# [CV] neuron1=4, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=4, score=-0.000, total=   8.4s
# [CV] neuron1=4, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=8, score=-0.000, total=   9.0s
# [CV] neuron1=4, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=8, score=-0.000, total=   9.6s
# [CV] neuron1=4, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=8, score=-0.000, total=   9.4s
# [CV] neuron1=4, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=8, score=-0.000, total=   8.8s
# [CV] neuron1=4, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=4, neuron2=16, neuron3=8, score=-0.000, total=   9.9s
# [CV] neuron1=4, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=4, neuron2=16, neuron3=16, score=-0.000, total=   9.1s
# [CV] neuron1=4, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=4, neuron2=16, neuron3=16, score=-0.000, total=   8.8s
# [CV] neuron1=4, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=4, neuron2=16, neuron3=16, score=-0.000, total=   9.3s
# [CV] neuron1=4, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=4, neuron2=16, neuron3=16, score=-0.000, total=  10.5s
# [CV] neuron1=4, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=4, neuron2=16, neuron3=16, score=-0.000, total=   9.0s
# [CV] neuron1=8, neuron2=4, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=4, score=-0.000, total=   8.6s
# [CV] neuron1=8, neuron2=4, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=4, score=-0.000, total=   9.6s
# [CV] neuron1=8, neuron2=4, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=4, score=-0.000, total=  10.7s
# [CV] neuron1=8, neuron2=4, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=4, score=-0.000, total=   9.4s
# [CV] neuron1=8, neuron2=4, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=4, score=-0.000, total=   8.9s
# [CV] neuron1=8, neuron2=4, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=8, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=4, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=8, score=-0.000, total=   8.3s
# [CV] neuron1=8, neuron2=4, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=8, score=-0.000, total=   8.2s
# [CV] neuron1=8, neuron2=4, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=8, score=-0.000, total=   8.2s
# [CV] neuron1=8, neuron2=4, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=4, neuron3=8, score=-0.000, total=   8.3s
# [CV] neuron1=8, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=4, neuron3=16, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=4, neuron3=16, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=4, neuron3=16, score=-0.000, total=   8.7s
# [CV] neuron1=8, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=4, neuron3=16, score=-0.000, total=   8.6s
# [CV] neuron1=8, neuron2=4, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=4, neuron3=16, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=4, score=-0.000, total=   8.2s
# [CV] neuron1=8, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=4, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=4, score=-0.000, total=   8.2s
# [CV] neuron1=8, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=4, score=-0.000, total=   8.1s
# [CV] neuron1=8, neuron2=8, neuron3=4 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=4, score=-0.000, total=   8.1s
# [CV] neuron1=8, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=8, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=8, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=8, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=8, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=8, neuron3=8 .................................
# [CV] .... neuron1=8, neuron2=8, neuron3=8, score=-0.000, total=   8.3s
# [CV] neuron1=8, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=8, neuron3=16, score=-0.000, total=   8.9s
# [CV] neuron1=8, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=8, neuron3=16, score=-0.000, total=   8.8s
# [CV] neuron1=8, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=8, neuron3=16, score=-0.000, total=   8.9s
# [CV] neuron1=8, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=8, neuron3=16, score=-0.000, total=   9.1s
# [CV] neuron1=8, neuron2=8, neuron3=16 ................................
# [CV] ... neuron1=8, neuron2=8, neuron3=16, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=4, score=-0.000, total=   8.6s
# [CV] neuron1=8, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=4, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=4, score=-0.000, total=   8.4s
# [CV] neuron1=8, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=4, score=-0.000, total=   8.6s
# [CV] neuron1=8, neuron2=16, neuron3=4 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=4, score=-0.000, total=   9.6s
# [CV] neuron1=8, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=8, score=-0.000, total=   9.0s
# [CV] neuron1=8, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=8, score=-0.000, total=   8.7s
# [CV] neuron1=8, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=8, score=-0.000, total=   9.1s
# [CV] neuron1=8, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=8, score=-0.000, total=   8.3s
# [CV] neuron1=8, neuron2=16, neuron3=8 ................................
# [CV] ... neuron1=8, neuron2=16, neuron3=8, score=-0.000, total=   8.3s
# [CV] neuron1=8, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=8, neuron2=16, neuron3=16, score=-0.000, total=   8.6s
# [CV] neuron1=8, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=8, neuron2=16, neuron3=16, score=-0.000, total=   8.7s
# [CV] neuron1=8, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=8, neuron2=16, neuron3=16, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=8, neuron2=16, neuron3=16, score=-0.000, total=   8.5s
# [CV] neuron1=8, neuron2=16, neuron3=16 ...............................
# [CV] .. neuron1=8, neuron2=16, neuron3=16, score=-0.000, total=   8.5s
# [CV] neuron1=16, neuron2=4, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=4, score=-0.000, total=   7.8s
# [CV] neuron1=16, neuron2=4, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=4, score=-0.000, total=   7.7s
# [CV] neuron1=16, neuron2=4, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=4, score=-0.000, total=   7.8s
# [CV] neuron1=16, neuron2=4, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=4, score=-0.000, total=   8.0s
# [CV] neuron1=16, neuron2=4, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=4, score=-0.000, total=   7.7s
# [CV] neuron1=16, neuron2=4, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=8, score=-0.000, total=  10.6s
# [CV] neuron1=16, neuron2=4, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=8, score=-0.000, total=   9.9s
# [CV] neuron1=16, neuron2=4, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=8, score=-0.000, total=  11.2s
# [CV] neuron1=16, neuron2=4, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=8, score=-0.000, total=  10.2s
# [CV] neuron1=16, neuron2=4, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=4, neuron3=8, score=-0.000, total=   9.4s
# [CV] neuron1=16, neuron2=4, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=4, neuron3=16, score=-0.000, total=   9.0s
# [CV] neuron1=16, neuron2=4, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=4, neuron3=16, score=-0.000, total=   8.9s
# [CV] neuron1=16, neuron2=4, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=4, neuron3=16, score=-0.000, total=  11.3s
# [CV] neuron1=16, neuron2=4, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=4, neuron3=16, score=-0.000, total=   9.8s
# [CV] neuron1=16, neuron2=4, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=4, neuron3=16, score=-0.000, total=  12.0s
# [CV] neuron1=16, neuron2=8, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=4, score=-0.000, total=  11.3s
# [CV] neuron1=16, neuron2=8, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=4, score=-0.000, total=  10.0s
# [CV] neuron1=16, neuron2=8, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=4, score=-0.000, total=   9.6s
# [CV] neuron1=16, neuron2=8, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=4, score=-0.000, total=  10.4s
# [CV] neuron1=16, neuron2=8, neuron3=4 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=4, score=-0.000, total=   9.7s
# [CV] neuron1=16, neuron2=8, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=8, score=-0.000, total=  10.1s
# [CV] neuron1=16, neuron2=8, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=8, score=-0.000, total=   9.1s
# [CV] neuron1=16, neuron2=8, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=8, score=-0.000, total=   8.7s
# [CV] neuron1=16, neuron2=8, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=8, score=-0.000, total=   8.7s
# [CV] neuron1=16, neuron2=8, neuron3=8 ................................
# [CV] ... neuron1=16, neuron2=8, neuron3=8, score=-0.000, total=   9.5s
# [CV] neuron1=16, neuron2=8, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=8, neuron3=16, score=-0.000, total=  10.4s
# [CV] neuron1=16, neuron2=8, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=8, neuron3=16, score=-0.000, total=   8.8s
# [CV] neuron1=16, neuron2=8, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=8, neuron3=16, score=-0.000, total=   9.1s
# [CV] neuron1=16, neuron2=8, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=8, neuron3=16, score=-0.000, total=   9.3s
# [CV] neuron1=16, neuron2=8, neuron3=16 ...............................
# [CV] .. neuron1=16, neuron2=8, neuron3=16, score=-0.000, total=   8.6s
# [CV] neuron1=16, neuron2=16, neuron3=4 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=4, score=-0.000, total=   8.2s
# [CV] neuron1=16, neuron2=16, neuron3=4 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=4, score=-0.000, total=   8.5s
# [CV] neuron1=16, neuron2=16, neuron3=4 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=4, score=-0.000, total=   8.3s
# [CV] neuron1=16, neuron2=16, neuron3=4 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=4, score=-0.000, total=   8.4s
# [CV] neuron1=16, neuron2=16, neuron3=4 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=4, score=-0.000, total=   8.7s
# [CV] neuron1=16, neuron2=16, neuron3=8 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=8, score=-0.000, total=   8.5s
# [CV] neuron1=16, neuron2=16, neuron3=8 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=8, score=-0.000, total=   8.4s
# [CV] neuron1=16, neuron2=16, neuron3=8 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=8, score=-0.000, total=   8.7s
# [CV] neuron1=16, neuron2=16, neuron3=8 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=8, score=-0.000, total=   8.6s
# [CV] neuron1=16, neuron2=16, neuron3=8 ...............................
# [CV] .. neuron1=16, neuron2=16, neuron3=8, score=-0.000, total=   8.4s
# [CV] neuron1=16, neuron2=16, neuron3=16 ..............................
# [CV] . neuron1=16, neuron2=16, neuron3=16, score=-0.000, total=   8.8s
# [CV] neuron1=16, neuron2=16, neuron3=16 ..............................
# [CV] . neuron1=16, neuron2=16, neuron3=16, score=-0.000, total=   8.9s
# [CV] neuron1=16, neuron2=16, neuron3=16 ..............................
# [CV] . neuron1=16, neuron2=16, neuron3=16, score=-0.000, total=   8.6s
# [CV] neuron1=16, neuron2=16, neuron3=16 ..............................
# [CV] . neuron1=16, neuron2=16, neuron3=16, score=-0.000, total=   8.7s
# [CV] neuron1=16, neuron2=16, neuron3=16 ..............................
# [CV] . neuron1=16, neuron2=16, neuron3=16, score=-0.000, total=   8.6s
# [Parallel(n_jobs=1)]: Done 135 out of 135 | elapsed: 19.9min finished

# %%
# summerize results
print('Best:{}, using {}'.format(grid_result.best_score_, grid_result.best_params_))
means= grid_result.cv_results_['mean_test_score']
stds= grid_result.cv_results_['std_test_score']
params= grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best:-0.00011257029545959085, using {'neuron1': 8, 'neuron2': 8, 'neuron3': 16}
# -0.00012605278461705894,2.6121795627152546e-05 with: {'neuron1': 4, 'neuron2': 4, 'neuron3': 4}
# -0.00012949843076057733,2.483321005169154e-05 with: {'neuron1': 4, 'neuron2': 4, 'neuron3': 8}
# -0.0001172794567537494,1.8480531017938696e-05 with: {'neuron1': 4, 'neuron2': 4, 'neuron3': 16}
# -0.000123000267194584,1.256018809604433e-05 with: {'neuron1': 4, 'neuron2': 8, 'neuron3': 4}
# -0.00011717116722138598,1.594616146212684e-05 with: {'neuron1': 4, 'neuron2': 8, 'neuron3': 8}
# -0.00012314627529121935,2.8843241449503726e-05 with: {'neuron1': 4, 'neuron2': 8, 'neuron3': 16}
# -0.00012457311968319117,2.0093728206883007e-05 with: {'neuron1': 4, 'neuron2': 16, 'neuron3': 4}
# -0.00011817652557510883,2.0362530115419334e-05 with: {'neuron1': 4, 'neuron2': 16, 'neuron3': 8}
# -0.00013281875289976596,1.6894908656530374e-05 with: {'neuron1': 4, 'neuron2': 16, 'neuron3': 16}
# -0.00013163082621758804,1.5270275586453304e-05 with: {'neuron1': 8, 'neuron2': 4, 'neuron3': 4}
# -0.00011536108213476837,1.9074168940740467e-05 with: {'neuron1': 8, 'neuron2': 4, 'neuron3': 8}
# -0.00014120604755589737,3.994207002342677e-05 with: {'neuron1': 8, 'neuron2': 4, 'neuron3': 16}
# -0.00011348589177941903,1.6644059094711104e-05 with: {'neuron1': 8, 'neuron2': 8, 'neuron3': 4}
# -0.0001165895038866438,2.5580236949111888e-05 with: {'neuron1': 8, 'neuron2': 8, 'neuron3': 8}
# -0.00011257029545959085,1.5647868551039204e-05 with: {'neuron1': 8, 'neuron2': 8, 'neuron3': 16}
# -0.00013957382179796696,4.354606320121944e-06 with: {'neuron1': 8, 'neuron2': 16, 'neuron3': 4}
# -0.00012496169074438512,2.4484464231661672e-05 with: {'neuron1': 8, 'neuron2': 16, 'neuron3': 8}
# -0.0001230510650202632,2.8046364173064462e-05 with: {'neuron1': 8, 'neuron2': 16, 'neuron3': 16}
# -0.00012156359443906694,2.2710577072382627e-05 with: {'neuron1': 16, 'neuron2': 4, 'neuron3': 4}
# -0.00012640427885344253,1.635500240238186e-05 with: {'neuron1': 16, 'neuron2': 4, 'neuron3': 8}
# -0.00014079058892093598,1.6883909893709762e-05 with: {'neuron1': 16, 'neuron2': 4, 'neuron3': 16}
# -0.00012594961153808982,1.4029936728304677e-05 with: {'neuron1': 16, 'neuron2': 8, 'neuron3': 4}
# -0.00011514448560774326,2.3428644511988474e-05 with: {'neuron1': 16, 'neuron2': 8, 'neuron3': 8}
# -0.00011905986466445028,2.9870300427099604e-05 with: {'neuron1': 16, 'neuron2': 8, 'neuron3': 16}
# -0.0001275076894671656,2.3474447600566812e-05 with: {'neuron1': 16, 'neuron2': 16, 'neuron3': 4}
# -0.00011813350283773616,1.9079102192200657e-05 with: {'neuron1': 16, 'neuron2': 16, 'neuron3': 8}
# -0.00012480359728215263,3.038990635636747e-05 with: {'neuron1': 16, 'neuron2': 16, 'neuron3': 16}

# %%
# Model using optimum hyperparameters
# Tuning parameter: Number of neurons in activation layer

# %%
def create_model_opt():
  model= Sequential()
  model.add(Dense(16, input_dim=10, kernel_initializer= 'normal', activation='linear'))
  model.add(Dropout(0))
  model.add(Dense(8, kernel_initializer= 'normal', activation='linear'))
  model.add(Dropout(0))
  model.add(Dense(8, kernel_initializer= 'normal', activation='linear'))
  model.add(Dropout(0))
  model.add(Dense(1, kernel_initializer= 'normal', activation='linear')) 
  adam= Adam(learning_rate= 0.001)
# Compile model
  model.compile(loss='mean_squared_error', optimizer=adam)
  return model

# Define regression model
model= KerasRegressor(build_fn=create_model_opt, verbose=10, batch_size=100, epochs=100)
# Fitting model
estimator= model.fit(x,y)
kfold= KFold(n_splits=10, random_state=1, shuffle=True)
results= cross_val_score(model, x,y, cv= kfold)
print('mse:', results.mean())
# Out:
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# mse: -0.00011395708061172627

# %%
print('MSE',results.mean())
# Out:
# MSE -0.00011395708061172627
